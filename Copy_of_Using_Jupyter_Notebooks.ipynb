# %% [markdown]
# <a href="https://colab.research.google.com/github/AISWARYAR2001/Assignment-day1/blob/main/Copy_of_Using_Jupyter_Notebooks.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Using Jupyter Notebooks

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn
# %matplotlib inline

# %%
a = np.arange(10,21)
b = np.arange(20,31)

plt.title("Question 1:", color='Red')
plt.xlabel("X-Axis", color='Blue')
plt.ylabel("Y-Axis", color='Blue')
plt.plot(a,b,'r*--',linewidth=1,markersize=13)
plt.show()

# %%
days = [1,2,3,4,5,6,7]
sales_1 = [140,150,140,145,15,65,200] #company1
sales_2 = [170,90,60,50,240,45,195] #company2

plt.title("Question 2: ",color='red')
plt.xlabel("X-Axis", color='blue')
plt.ylabel("Y-Axis", color='blue')

plt.plot(days, sales_1, 'ro--', markersize=12, linewidth=2)
plt.plot(days, sales_2, 'g*--', markersize=12, linewidth=2)
plt.show()

# %%
x = [1,2,3,4]
y1 = [4,3,2,1]
y2 = [10,2,30,40]
y3 = [40,30,20,10]
y4 = [1,2,1,2]
y5 = [40,70,90,70]
y6 = [30,40,10,60]

plt.subplots(figsize=(20,20))
plt.subplot(3,2,1)
plt.xlabel("X-Axis", color='blue')
plt.ylabel("Y-Axis", color='blue')
plt.plot(x,y1,'go--')

plt.subplot(3,2,2)
plt.xlabel("X-Axis", color='blue')
plt.ylabel("Y-Axis", color='blue')
plt.plot(x,y2,'go--')

plt.subplot(3,2,3)
plt.xlabel("X-Axis", color='blue')
plt.ylabel("Y-Axis", color='blue')
plt.plot(x,y3,'go--')

plt.subplot(3,2,4)
plt.xlabel("X-Axis", color='blue')
plt.ylabel("Y-Axis", color='blue')
plt.plot(x,y4,'go--')

plt.subplot(3,2,5)
plt.xlabel("X-Axis", color='blue')
plt.ylabel("Y-Axis", color='blue')
plt.plot(x,y5,'go--')

plt.subplot(3,2,6)
plt.xlabel("X-Axis", color='blue')
plt.ylabel("Y-Axis", color='blue')
plt.plot(x,y6,'go--')
